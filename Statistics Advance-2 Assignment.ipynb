# %% [markdown]
# Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the
# z-statistic used in hypothesis testing?

# %% [markdown]
# Definition of the Z-Statistic:
#
# The z-statistic is a numerical measurement that describes a value's relationship to the mean of a group of values, expressed in terms of standard deviations. The formula for calculating the z-statistic for a single sample is:
#
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )/
# 𝜎
#
#
# Where:
#
#
# X is the sample mean.
#
#
# μ is the population mean.
#
#
# σ is the standard deviation of the population.
#
# Relationship to the Standard Normal Distribution:
#
# The z-statistic is directly related to the standard normal distribution, which is a normal distribution with a mean of 0 and a standard deviation of 1. When data is standardized (converted into z-scores), it allows for comparisons across different distributions.

# %% [markdown]
# Usage of the Z-Statistic in Hypothesis Testing:
#
# 1. State the Hypotheses:
#
# Null Hypothesis (
# 𝐻
# 0
#  ): Assumes no effect or difference (e.g.,
# H
# 0
# ​
#  :μ=μ
# 0
# ​
#  ).
#
# Alternative Hypothesis (
# 𝐻
# 𝑎
# ​
#  ): Assumes there is an effect or difference (e.g.,
# 𝐻
# 𝑎
# :
# 𝜇
# ≠
# 𝜇
# 0
#  ).
# 2. Calculate the Z-Statistic: Use the formula
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )/
# 𝜎
#
#   to find the z-statistic based on the sample data.
#
# 3. Determine the Critical Value: Find the critical z-value(s) corresponding to the significance level (e.g., 0.05) from the standard normal distribution table.
#
# 4. Make a Decision:
# Reject
# 𝐻
# 0
#   if the z-statistic exceeds the critical value.
# Do not reject
# 𝐻
# 0
#   if the z-statistic does not exceed the critical value.
# 5. Draw a Conclusion: Interpret the results in the context of the research question, indicating whether there is sufficient evidence to support the alternative hypothesis.

# %% [markdown]
# Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is
# very small (e.g., 0.01)?

# %% [markdown]
# Definition: The p-value is the probability of obtaining results as extreme as the observed data, assuming the null hypothesis (
# 𝐻
# 0
#  ) is true.
#
# Usage:
#
# 1. Set Hypotheses:
#
# Null Hypothesis (
# H
# 0
# ​
#  ): No effect or difference.
#
# Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): There is an effect or difference.
# 2. Calculate the P-Value: Determine the p-value from the test statistic.
# 3. Compare with Significance Level (
# α):
# If
# p-value≤α (commonly 0.05), reject
# H
# 0
# ​
#   (statistically significant).
#
# If
# p-value>α, do not reject
# H
# 0
# ​
#  .
#
# Interpretation of a Small P-Value (e.g., 0.01): Indicates strong evidence against
# 𝐻
# 0
# ​
#  , suggesting that the observed results are statistically significant and unlikely to be due to random chance.

# %% [markdown]
# Question3: Compare and contrast the binomial and Bernoulli distributions.

# %% [markdown]
# 1. Definition
#
# Bernoulli Distribution: Represents a single trial with two possible outcomes: success (with probability
# p) or failure (with probability
# 1−p).
# Example: Tossing a coin once, where heads (success) occurs with a probability of
# p=0.5.
#
# Binomial Distribution: Describes the number of successes in a fixed number (
# n) of independent Bernoulli trials, each with the same probability of success
# p.
# Example: Tossing a coin 10 times and counting how many heads occur.
#
# 2. Key Parameters
# Bernoulli:
#
# Probability of success:
# p
#
# Only one trial (
# n=1 )
#
# Binomial:
#
# Number of trials:
# n
#
# Probability of success in each trial:
# p
#
# 3. Range of Values
#
# Bernoulli: The random variable
# X takes on values 0 (failure) or 1 (success).
#
# Binomial: The random variable
# X takes on integer values from 0 to
# n, representing the number of successes in
# n trials.
#
# 4. Relationship
#
# A Bernoulli distribution is a special case of the binomial distribution where
# n=1.
#
# The binomial distribution is essentially the sum of multiple independent Bernoulli trials.
#
# 5. Example
#
# Bernoulli: Flipping a coin once.
#
# Binomial: Flipping a coin 10 times and counting how many heads you get.

# %% [markdown]
# Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli
# distribution?

# %% [markdown]
# Conditions for Using the Binomial Distribution
#
#
# 1. Fixed Number of Trials (n): The experiment is repeated a set number of times.
#
# Example: Rolling a die 10 times.
# 2. Binary Outcomes: Each trial results in one of two outcomes: success or failure.
#
# Example: Getting heads or tails in a coin toss.
#
# 3. Constant Probability of Success (p): The probability of success remains the same for each trial.
#
# Example: The probability of flipping heads with a fair coin is always 0.5.
# 4. Independence: Each trial is independent of the others. The outcome of one trial does not affect the outcome of another.
#
# Example: The result of one die roll doesn’t influence subsequent rolls.
#
#
#
#
# Relationship to the Bernoulli Distribution:
#
# The binomial distribution is essentially a generalization of the Bernoulli distribution. Specifically:
#
#
# Bernoulli Distribution: Describes a single trial (
# n=1 ) with two outcomes (success or failure). The probability of success is
# p.
#
# Binomial Distribution: Describes the total number of successes across multiple (
# n ) independent Bernoulli trials. Each trial has the same probability of success p.

# %% [markdown]
# Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this
# distribution?

# %% [markdown]
# Key Properties of the Poisson Distribution
#
# 1. Discrete Distribution: The Poisson distribution is used for counting the number of occurrences of an event in a fixed interval (e.g., time, distance, area).
#
# 2. Non-Negative Integer Values: The random variable
# X, representing the number of events, takes on values 0, 1, 2, 3, etc.
#
# 3. Single Parameter (
# λ):
# λ represents the average number of events in a given interval (also known as the rate).
# The mean and variance of the distribution are both equal to
# λ.
# 4. Events Occur Independently: The occurrence of one event does not affect the probability of another event occurring.
#
# 5. Low Probability, High Frequency: The probability of any one event happening is low, but events occur frequently within the given interval.
#
# 6. Memoryless Property: The Poisson process is memoryless, meaning the probability of future events depends only on the current state and not on prior events.

# %% [markdown]
# When to Use the Poisson Distribution
#
#
# 1. Counting Rare Events: The Poisson distribution is used to model the number of rare events occurring in a fixed interval of time, space, or distance.
#
# Example: Number of emails received per hour.
#
# 2. Constant Rate (
# λ): The average rate at which events occur remains constant over the interval.
#
# Example: An average of 5 customer arrivals per minute.
# 3. Independence: Events occur independently of each other.
#
# Example: The arrival of buses at a station is independent of each other.
# 4. Small Probability, Large Number of Trials: The probability of each individual event is small, but the number of trials or possible occurrences is large.
#
# Example: Number of defects in a large batch of products.

# %% [markdown]
# Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a
# PDF differ from a probability mass function (PMF)?

# %% [markdown]
# Probability Distribution
#
# A probability distribution describes how the probabilities of different outcomes are distributed for a random variable. It shows the likelihood of each possible value or range of values that a random variable can take.
#
# For Discrete Variables: Describes the probabilities of individual values (e.g., outcomes of rolling a die).
#
# For Continuous Variables: Describes the probability of the random variable falling within a certain range (e.g., a person’s height).
#
# Probability Density Function (PDF)
# A probability density function (PDF) is used to describe the probability distribution of a continuous random variable. It gives the relative likelihood that the variable will take a particular value within a range.
#
# The PDF itself does not give the probability for specific values but instead the probability of the variable falling within a range.
# The area under the PDF curve over an interval represents the probability that the variable falls within that interval.

# %% [markdown]
# Difference Between PDF and PMF
#
# Probability Mass Function (PMF):Used for discrete random variables.
#
# Gives the probability of the random variable taking a specific value.
# Example: For a die roll,
# P(X=2)=1/6.
#
#
# Probability Density Function (PDF):
# Used for continuous random variables.
#
# Gives the relative likelihood of the variable being near a particular value. The actual probability of taking any specific value is zero because the variable can take infinitely many values within a range.
# Example: The probability of a person’s height being exactly 170 cm is 0, but the PDF helps calculate the probability of the height falling within a range (e.g., between 170 cm and 175 cm).

# %% [markdown]
# Question7: Explain the Central Limit Theorem (CLT) with example.

# %% [markdown]
# Central limit theorem
#
# When a large enough sample size is drawn from any population with a finite mean and variance, the sampling distribution of the sample mean will approach a normal distribution, regardless of the shape of the original population distribution.

# %% [markdown]
# Key Points of the CLT:
#
# 1. Sample Size: The larger the sample size, the more the sampling distribution of the sample mean will resemble a normal distribution. A common rule of thumb is a sample size of 30 or more is sufficient, although this can vary depending on the original population distribution.
#
# 2. Population Distribution: The original population can be of any distribution (e.g., skewed, uniform, or even binomial). As long as you take sufficiently large random samples, the distribution of the sample means will approximate a normal distribution.
#
# 3. Mean and Variance:
#
# The mean of the sampling distribution will be approximately equal to the population mean (μ).
#
# The standard deviation of the sampling distribution (known as the standard error) will be the population standard deviation (σ) divided by the square root of the sample size (n)

# %% [markdown]
# Example of Central Limit Theorem
#
#
# Population: Suppose we have a population of exam scores that follow a right-skewed distribution, with most students scoring low and a few scoring very high.
#
# Sample: Now, we randomly draw samples of size
# n=50 from this population and calculate the mean score for each sample.
#
# Result:
#
# Even though the population distribution of exam scores is skewed, according to the CLT, the sampling distribution of the sample means (i.e., the distribution of all possible sample means from the population) will tend to follow a normal distribution as the sample size increases.
# If we keep taking different random samples of size 50, plot their means, and repeat this many times, we’ll observe that the distribution of those means forms a bell-shaped curve, i.e., a normal distribution.

# %% [markdown]
# Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?

# %% [markdown]
# Comparison of Z-Scores and T-Scores
#
# Both z-scores and t-scores are used in hypothesis testing and confidence interval estimation, but they are applied under different conditions based on the data and sample size.
#
#
# Z-Score
#
# Definition: A z-score measures how many standard deviations a data point or sample mean is from the population mean.
#
# z= X−μ/σ
#
#
# Where:
#
# X = sample mean or value
#
# μ = population mean
#
# σ = population standard deviation
#
# Usage: The z-score is used when:
#
# The population standard deviation (
# σ) is known.
#
# The sample size is large (n > 30).
#
# The population follows a normal distribution (or the sample size is large enough for the Central Limit Theorem to apply).
#
#
# T-Score
#
# Definition: A t-score is similar to a z-score but is used when the population standard deviation is unknown, and the sample size is small. It accounts for additional uncertainty due to the small sample size.
#
# t=
#  X−μ/s/√n
#
#
# Where:
#
#
# X = sample mean
#
# μ = population mean (hypothesized)
#
# s = sample standard deviation
#
# n = sample size
#
# Usage: The t-score is used when:
#
# The population standard deviation is unknown.
#
# The sample size is small (n ≤ 30).
#
# The population follows a normal distribution or is approximately normal.

# %% [markdown]
# When to Use a Z-Score vs. T-Score
#
# Use a Z-Score:
#
# When the sample size is large (usually
# n>30).
#
# When the population standard deviation (
# σ) is known.
#
# Use a T-Score:
#
# When the sample size is small (usually
# n≤30).
#
# When the population standard deviation is unknown (and the sample standard deviation
# s is used instead)

# %% [markdown]
# Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to
# reject the null hypothesis?
#
#  Task: Write Python code to calculate the z-score and p-value for the given data.
#
# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.

# %%
from scipy import stats

#Given data
sample_mean = 105
population_mean = 100
std_dev = 15
sample_size = 25

#z score calculation
z_score = (sample_mean - population_mean) / (std_dev / (sample_size ** 0.5))

#p value calculation
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

#Significance level
alpha = 0.05

# Determine whether to reject the null hypothesis
reject_null = p_value < alpha

z_score, p_value, reject_null
# Out:
# (1.6666666666666667, 0.09558070454562939, False)

# %% [markdown]
# Conclusion:
#
# Since the p-value is greater than the significance level of 0.05, we fail to reject the null hypothesis.
#
# This indicates that there is not enough evidence to suggest that the sample mean of 105 is significantly different from the population mean of 100.

# %% [markdown]
# Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?
#
# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.
#
# Objective: Understand the properties of a binomial distribution and verify them through simulation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

n_trials = 10
p_success = 0.6
n_samples = 1000

# Simulate binomial distribution
samples = np.random.binomial(n_trials, n_success, n_samples)

#Calculate mean and variance
expected_mean = n_trials * p_success
expected_variance = n_trials * p_success * (1 - p_success)

# Plot the distribution
sns.histplot(samples,bins=np.arange(-0.5, n_trials + 1.5, 1), kde=False, stat = 'density')
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n_trials + 1))
plt.grid()
plt.show()

# %%
expected_mean, expected_variance
# Out:
# (6.0, 2.4000000000000004)

# %% [markdown]
# Interpretation
#
# The simulated binomial distribution reflects the theoretical properties:
#
# The mean of the distribution is 6.0, indicating that, on average, we expect 6 successes in 10 trials.
#
# The variance of the distribution is 2.4, which indicates the degree of variability around the mean.
